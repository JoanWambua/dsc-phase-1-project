# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %% [markdown]
# #  Film Industry Analysis for Microsoft

# %% [markdown]
# ![MICROSOFT%20LOGO.jpg](attachment:MICROSOFT%20LOGO.jpg)

# %% [markdown]
# Author: Joan Wambua

# %% [markdown]
# ## Overview
#
# Microsoft is venturing into the realm of original video content creation by establishing a new movie studio. However, with limited expertise in the field, they are in need of insights to guide their filmmaking endeavors. The challenge at hand is to identify the types of films that are currently performing exceptionally well at the box office. This exploration aims to provide actionable insights that will empower Microsoft's movie studio leadership to make informed decisions on the genre and style of films to produce. By understanding the key factors contributing to box office success, Microsoft can strategically enter the entertainment industry and create content that resonates with audiences and maximizes profitability.

# %% [markdown]
# ## Business Problem
# Microsoft is starting a movie studio but doesn't know what movies to make. They want to find out which movie types are popular at the box office. Their new movie studio leadership will be able make informed decisions on the genre and style of films to produce, allowing them to enter the Film Industry and compete effectively in the entertainment industry.

# %% [markdown]
# ## Data Understanding
# 3 different datasets are used for this Exploratory Data Analysis. These include;
#
# 1. bom.movie_gross; which entails the domestic and foreign gross revenue figures different movies earned after production. This particular dataset will guide Microsoft to understand which movies and genres earn more and which ones to invest in.
#
# 2. title.basics.tsv.gz; which entails titles of movies and their genres. This file will especially guide Microsoft to understand in depth about the movie genres that are in the industry.
#
# 3. title.ratings.tsv.gz; which inludes the average ratings a movie gets once it is released and also the number of votes it acquires.

# %% [markdown]
# First, ensure that the files we need for this analysis are in this notebook by using the ls command which prints the contents of this file.

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is C8B8-0896
#
#  Directory of C:\Users\wambu\PHASE1_PROJECT\dsc-phase-1-project
#
# 03/11/2023  06:21    <DIR>          .
# 01/11/2023  08:51    <DIR>          ..
# 01/11/2023  08:52               140 .canvas
# 01/11/2023  08:52                80 .gitignore
# 01/11/2023  08:56    <DIR>          .ipynb_checkpoints
# 01/11/2023  08:52         1,425,341 awesome.gif
# 01/11/2023  09:23            53,544 bom.movie_gross.csv.gz
# 01/11/2023  08:52             1,846 CONTRIBUTING.md
# 01/11/2023  08:52             1,357 LICENSE.md
# 03/11/2023  01:08            10,792 MICROSOFT LOGO.jpg
# 01/11/2023  08:52             4,676 README.md
# 03/11/2023  06:21           471,357 student.ipynb
# 01/11/2023  09:24       179,586,990 title.basics.tsv.gz
# 01/11/2023  09:23         6,860,335 title.ratings.tsv.gz
# 01/11/2023  08:52    <DIR>          zippedData
#               11 File(s)    188,416,458 bytes
#                4 Dir(s)  414,306,254,848 bytes free

# %% [markdown]
# ## DATASET 1

# %% [markdown]
# Import pandas library inorder to read the first file
# Import the gzip tool to unzip our compressed files.

# %%
import pandas as pd
import gzip

file_path = 'bom.movie_gross.csv.gz'
with gzip.open(file_path, 'rb') as file:
    movie_gross_df = pd.read_csv(file)

# %%
movie_gross_df.head(10)
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
# 5                   The Twilight Saga: Eclipse   Sum.     300500000.0
# 6                                   Iron Man 2   Par.     312400000.0
# 7                                      Tangled     BV     200800000.0
# 8                                Despicable Me   Uni.     251500000.0
# 9                     How to Train Your Dragon   P/DW     217600000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010
# 5     398000000  2010
# 6     311500000  2010
# 7     391000000  2010
# 8     291600000  2010
# 9     277300000  2010

# %% [markdown]
# As seen above, you can see that some movies are distributed by more than one studio eg. How to Train Your Dragon was distributed by Paramount Pictures and DreamWorks studios. This is called Co-Production which involves multiple production companies and financing from various countries.

# %%
movie_gross_df.tail(10)
# Out:
#                              title      studio  domestic_gross foreign_gross  \
# 3377               Let Yourself Go        Men.         12200.0           NaN
# 3378                 Hannah (2018)         PDF         11700.0           NaN
# 3379                      Souvenir      Strand         11400.0           NaN
# 3380  Furious (Legend of Kolovrat)     CARUSEL         10000.0           NaN
# 3381           Beauty and the Dogs       Osci.          8900.0           NaN
# 3382                     The Quake       Magn.          6200.0           NaN
# 3383   Edward II (2018 re-release)          FM          4800.0           NaN
# 3384                      El Pacto        Sony          2500.0           NaN
# 3385                      The Swan  Synergetic          2400.0           NaN
# 3386             An Actor Prepares       Grav.          1700.0           NaN
#
#       year
# 3377  2018
# 3378  2018
# 3379  2018
# 3380  2018
# 3381  2018
# 3382  2018
# 3383  2018
# 3384  2018
# 3385  2018
# 3386  2018

# %% [markdown]
# Rows: 3387
# Columns with numeric data: 2
# Columns with categorical data: 3
# The dataset ranges from 2010 to 2018

# %%
movie_gross_df.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross      object
# year                int64
# dtype: object

# %% [markdown]
# From the above code, there are 2 columns that are objects. The year column is an integer while both gross columns should be float types. Next step is to convert the foreign gross column to type float64.

# %%
# Convert the column to float64
movie_gross_df['foreign_gross'] = pd.to_numeric(movie_gross_df['foreign_gross'], errors='coerce', downcast='float')

print(movie_gross_df.dtypes)
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross     float32
# year                int64
# dtype: object

# %%
movie_gross_df['foreign_gross'] = movie_gross_df['foreign_gross'].astype('float64')
print(movie_gross_df.dtypes['foreign_gross'])
# Out:
# float64

# %%
movie_gross_df.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross     float64
# year                int64
# dtype: object

# %% [markdown]
# Now that all columns have the correct datatypes, lets proceed to see the overall statistics summary and spread of your data.

# %%
movie_gross_df.describe()
# Out:
#        domestic_gross  foreign_gross         year
# count    3.359000e+03   2.032000e+03  3387.000000
# mean     2.874585e+07   7.505704e+07  2013.958075
# std      6.698250e+07   1.375294e+08     2.478141
# min      1.000000e+02   6.000000e+02  2010.000000
# 25%      1.200000e+05   3.775000e+06  2012.000000
# 50%      1.400000e+06   1.890000e+07  2014.000000
# 75%      2.790000e+07   7.505000e+07  2016.000000
# max      9.367000e+08   9.605000e+08  2018.000000

# %% [markdown]
# From the table above, we see that the mean of the foreign_gross income is significantly higher than that of the domestic gross income. The minimum, maximum and percentiles reflect this as well.

# %%
movie_gross_df.isna()
# Out:
#       title  studio  domestic_gross  foreign_gross   year
# 0     False   False           False          False  False
# 1     False   False           False          False  False
# 2     False   False           False          False  False
# 3     False   False           False          False  False
# 4     False   False           False          False  False
# ...     ...     ...             ...            ...    ...
# 3382  False   False           False           True  False
# 3383  False   False           False           True  False
# 3384  False   False           False           True  False
# 3385  False   False           False           True  False
# 3386  False   False           False           True  False
#
# [3387 rows x 5 columns]

# %%
movie_gross_df.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1355
# year                 0
# dtype: int64

# %% [markdown]
# From the above function, we see that the studio column has only 5 rows that have missing values.
# We also see that domestic_gross column has 28 missing values, with this we can replace the missing values with the mean from the table.
# We also see that the foreign_gross column has quite a big number of missing values, we shall inspect this a bit further and see whether to drop the entire column or not.

# %%
missing_rows = movie_gross_df[movie_gross_df['studio'].isna()]
print(missing_rows)
# Out:
#                               title studio  domestic_gross  foreign_gross  \
# 210   Outside the Law (Hors-la-loi)    NaN         96900.0      3300000.0
# 555         Fireflies in the Garden    NaN         70600.0      3300000.0
# 933           Keith Lemon: The Film    NaN             NaN      4000000.0
# 1862                 Plot for Peace    NaN          7100.0            NaN
# 2825               Secret Superstar    NaN             NaN    122000000.0
#
#       year
# 210   2010
# 555   2011
# 933   2012
# 1862  2014
# 2825  2017

# %% [markdown]
# Since there are only 5 rows in the studio column that contain Nan values, and it is quite tedious to figure out what all those initials in the column stand for, I will do away with the 5 rows. This is to avoid duplicating studio names without knowing what they mean or how their initials were created.

# %%
missing_rows = movie_gross_df[movie_gross_df['foreign_gross'].isna()]
print(missing_rows)
# Out:
#                                        title      studio  domestic_gross  \
# 222                                  Flipped          WB       1800000.0
# 254   The Polar Express (IMAX re-issue 2010)          WB        673000.0
# 267                           Tiny Furniture         IFC        392000.0
# 269            Grease (Sing-a-Long re-issue)        Par.        366000.0
# 280                          Last Train Home       Zeit.        288000.0
# ...                                      ...         ...             ...
# 3382                               The Quake       Magn.          6200.0
# 3383             Edward II (2018 re-release)          FM          4800.0
# 3384                                El Pacto        Sony          2500.0
# 3385                                The Swan  Synergetic          2400.0
# 3386                       An Actor Prepares       Grav.          1700.0
#
#       foreign_gross  year
# 222             NaN  2010
# 254             NaN  2010
# 267             NaN  2010
# 269             NaN  2010
# 280             NaN  2010
# ...             ...   ...
# 3382            NaN  2018
# 3383            NaN  2018
# 3384            NaN  2018
# 3385            NaN  2018
# 3386            NaN  2018
#
# [1355 rows x 5 columns]

# %% [markdown]
# With the foreign_gross column, I shall
# 1. Determine what percentage of rows in this column contain missing values
# 2. Print out the number of unique values in this column

# %%
print('Percentage of Null foreign_gross Values:', len(movie_gross_df[movie_gross_df.foreign_gross.isna()])/ len(movie_gross_df))
print('Number of Unique foreign_gross Values:', movie_gross_df.foreign_gross.nunique())
# Out:
# Percentage of Null foreign_gross Values: 0.40005904930617064
# Number of Unique foreign_gross Values: 1199

# %% [markdown]
# As seen from above, this is quite a significant amount of rows which have missing data. But when you look at the column and compare with values from the domestic column, you can see that the foreign_gross was higher than the domestic_gross. This being an important factor in the total income of a movie, I shall drop the rows with the missing values(40%) and work with the (60%) of the data.

# %%
# Delete rows with missing data in the 'foreign_gross' column
movie_gross_df.dropna(subset=['foreign_gross'], inplace=True)

# Print the DataFrame after removing rows with missing data
print(movie_gross_df)
# Out:
#                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross  foreign_gross  year
# 0        415000000.0    652000000.0  2010
# 1        334200000.0    691299968.0  2010
# 2        296000000.0    664300032.0  2010
# 3        292600000.0    535700000.0  2010
# 4        238700000.0    513900000.0  2010
# ...              ...            ...   ...
# 3275          1400.0      1500000.0  2018
# 3286        725000.0       229000.0  2018
# 3309         10000.0       256000.0  2018
# 3342         93200.0         5200.0  2018
# 3353         43200.0        30000.0  2018
#
# [2032 rows x 5 columns]

# %%
missing_rows = movie_gross_df[movie_gross_df['domestic_gross'].isna()]
print(missing_rows)
len(missing_rows)
# Out:
#                                       title   studio  domestic_gross  \
# 230              It's a Wonderful Afterlife      UTV             NaN
# 298   Celine: Through the Eyes of the World     Sony             NaN
# 302                              White Lion    Scre.             NaN
# 306                        Badmaash Company     Yash             NaN
# 327                      Aashayein (Wishes)  Relbig.             NaN
# 537                                   Force     FoxS             NaN
# 713                        Empire of Silver     NeoC             NaN
# 871                            Solomon Kane     RTWC             NaN
# 928                            The Tall Man    Imag.             NaN
# 933                   Keith Lemon: The Film      NaN             NaN
# 936                     Lula, Son of Brazil     NYer             NaN
# 966                          The Cup (2012)     Myr.             NaN
# 1017                              Dark Tide      WHE             NaN
# 1079                         The Green Wave       RF             NaN
# 1268                             22 Bullets    Cdgm.             NaN
# 1308             Matru Ki Bijlee Ka Mandola      FIP             NaN
# 1340                      The Snitch Cartel       PI             NaN
# 1342           All the Boys Love Mandy Lane     RTWC             NaN
# 1368                                6 Souls     RTWC             NaN
# 1659                             Jessabelle      LGF             NaN
# 1681                              14 Blades     RTWC             NaN
# 1685        Jack and the Cuckoo-Clock Heart   Shout!             NaN
# 1739                              Lila Lila    Crnth             NaN
# 1975         Surprise - Journey To The West       AR             NaN
# 2392                    Finding Mr. Right 2       CL             NaN
# 2468                                 Solace      LGP             NaN
# 2595                                  Viral   W/Dim.             NaN
# 2825                       Secret Superstar      NaN             NaN
#
#       foreign_gross  year
# 230       1300000.0  2010
# 298        119000.0  2010
# 302         99600.0  2010
# 306         64400.0  2010
# 327          3800.0  2010
# 537       4800000.0  2011
# 713         19000.0  2011
# 871      19600000.0  2012
# 928       5200000.0  2012
# 933       4000000.0  2012
# 936       3800000.0  2012
# 966       1800000.0  2012
# 1017       432000.0  2012
# 1079        70100.0  2012
# 1268     21300000.0  2013
# 1308      6000000.0  2013
# 1340      2100000.0  2013
# 1342      1900000.0  2013
# 1368       852000.0  2013
# 1659      7000000.0  2014
# 1681      3800000.0  2014
# 1685      3400000.0  2014
# 1739      1100000.0  2014
# 1975     49600000.0  2015
# 2392    114700000.0  2016
# 2468     22400000.0  2016
# 2595       552000.0  2016
# 2825    122000000.0  2017
# 28

# %% [markdown]
# Seeing that we still have 28 missing values in the foreign_values column, we shall then drop the Nan rows in the studio column then finally deal with the domestic_gross values

# %%
movie_gross_df.dropna(subset=['studio'], inplace=True)
print(movie_gross_df)
# Out:
#                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross  foreign_gross  year
# 0        415000000.0    652000000.0  2010
# 1        334200000.0    691299968.0  2010
# 2        296000000.0    664300032.0  2010
# 3        292600000.0    535700000.0  2010
# 4        238700000.0    513900000.0  2010
# ...              ...            ...   ...
# 3275          1400.0      1500000.0  2018
# 3286        725000.0       229000.0  2018
# 3309         10000.0       256000.0  2018
# 3342         93200.0         5200.0  2018
# 3353         43200.0        30000.0  2018
#
# [2028 rows x 5 columns]

# %% [markdown]
# Now that I have dropped the missing values from the studio column, let us see how many nan values are left in the domestic_gross value

# %%
missing_rows = movie_gross_df[movie_gross_df['domestic_gross'].isna()]
print(missing_rows)
len(missing_rows)
# Out:
#                                       title   studio  domestic_gross  \
# 230              It's a Wonderful Afterlife      UTV             NaN
# 298   Celine: Through the Eyes of the World     Sony             NaN
# 302                              White Lion    Scre.             NaN
# 306                        Badmaash Company     Yash             NaN
# 327                      Aashayein (Wishes)  Relbig.             NaN
# 537                                   Force     FoxS             NaN
# 713                        Empire of Silver     NeoC             NaN
# 871                            Solomon Kane     RTWC             NaN
# 928                            The Tall Man    Imag.             NaN
# 936                     Lula, Son of Brazil     NYer             NaN
# 966                          The Cup (2012)     Myr.             NaN
# 1017                              Dark Tide      WHE             NaN
# 1079                         The Green Wave       RF             NaN
# 1268                             22 Bullets    Cdgm.             NaN
# 1308             Matru Ki Bijlee Ka Mandola      FIP             NaN
# 1340                      The Snitch Cartel       PI             NaN
# 1342           All the Boys Love Mandy Lane     RTWC             NaN
# 1368                                6 Souls     RTWC             NaN
# 1659                             Jessabelle      LGF             NaN
# 1681                              14 Blades     RTWC             NaN
# 1685        Jack and the Cuckoo-Clock Heart   Shout!             NaN
# 1739                              Lila Lila    Crnth             NaN
# 1975         Surprise - Journey To The West       AR             NaN
# 2392                    Finding Mr. Right 2       CL             NaN
# 2468                                 Solace      LGP             NaN
# 2595                                  Viral   W/Dim.             NaN
#
#       foreign_gross  year
# 230       1300000.0  2010
# 298        119000.0  2010
# 302         99600.0  2010
# 306         64400.0  2010
# 327          3800.0  2010
# 537       4800000.0  2011
# 713         19000.0  2011
# 871      19600000.0  2012
# 928       5200000.0  2012
# 936       3800000.0  2012
# 966       1800000.0  2012
# 1017       432000.0  2012
# 1079        70100.0  2012
# 1268     21300000.0  2013
# 1308      6000000.0  2013
# 1340      2100000.0  2013
# 1342      1900000.0  2013
# 1368       852000.0  2013
# 1659      7000000.0  2014
# 1681      3800000.0  2014
# 1685      3400000.0  2014
# 1739      1100000.0  2014
# 1975     49600000.0  2015
# 2392    114700000.0  2016
# 2468     22400000.0  2016
# 2595       552000.0  2016
# 26

# %%
print('Percentage of Null domestic_gross Values:', len(movie_gross_df[movie_gross_df.domestic_gross.isna()])/ len(movie_gross_df))
print('Number of Unique domestic_gross Values:', movie_gross_df.domestic_gross.nunique())
# Out:
# Percentage of Null domestic_gross Values: 0.01282051282051282
# Number of Unique domestic_gross Values: 1290

# %% [markdown]
# As seen above, the domestic_gross nan values are quite little and instead of dropping the rows, I shall compute a placeholder value for these values using a central tendency. First, I will investigate the version of the gross_value column.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
domestic_gross_mean = movie_gross_df['domestic_gross'].mean()
domestic_gross_median = movie_gross_df['domestic_gross'].median()
movie_gross_df['domestic_gross'].plot(kind='hist', bins=5, color='b')

print("Mean Value for domestic_gross column: {}".format(domestic_gross_mean))
print("Median Value for domestic_gross column: {}".format(domestic_gross_median))
# Out:
# Mean Value for domestic_gross column: 45715294.34815185
# Median Value for domestic_gross column: 16399999.0

# %% [markdown]
# From the visualization above, we can see the data has a negative skew. I will proceed to replace the missing values with the median of the column.

# %%
movie_gross_df['domestic_gross'] = movie_gross_df['domestic_gross'].fillna(value=movie_gross_df['domestic_gross'].median)

# %%
movie_gross_df.isna().sum()
# Out:
# title             0
# studio            0
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %% [markdown]
# Now the missing data has been handled and we proceed to investigate 2 of our main factors using this dataset; Genre and Box Office Earnings. I will further use the movie titles provided with the earnings and try to understand their relationship.

# %%
movie_gross_df.dtypes
# Out:
# title              object
# studio             object
# domestic_gross     object
# foreign_gross     float64
# year                int64
# dtype: object

# %%
movie_gross_df['domestic_gross'] = pd.to_numeric(movie_gross_df['domestic_gross'], errors='coerce', downcast='float')

print(movie_gross_df.dtypes)
# Out:
# title              object
# studio             object
# domestic_gross    float32
# foreign_gross     float64
# year                int64
# dtype: object

# %%
movie_gross_df['domestic_gross'] = movie_gross_df['domestic_gross'].astype('float64')
print(movie_gross_df.dtypes['domestic_gross'])
# Out:
# float64

# %%
movie_gross_df.dtypes
# Out:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross     float64
# year                int64
# dtype: object

# %%
movie_gross_df
# Out:
#                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross  foreign_gross  year
# 0        415000000.0    652000000.0  2010
# 1        334200000.0    691299968.0  2010
# 2        296000000.0    664300032.0  2010
# 3        292600000.0    535700000.0  2010
# 4        238700000.0    513900000.0  2010
# ...              ...            ...   ...
# 3275          1400.0      1500000.0  2018
# 3286        725000.0       229000.0  2018
# 3309         10000.0       256000.0  2018
# 3342         93200.0         5200.0  2018
# 3353         43200.0        30000.0  2018
#
# [2028 rows x 5 columns]

# %% [markdown]
# We now have a cleaned dataset of 2028 rows and 5 columns.
# Now that our columns are inorder, I will illustrate the relationship between movie titles and gross earnings. I will do so through data visualization using seaborn as our tool.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sort the DataFrame by total gross (domestic + foreign) in descending order and select the first 10 movies
top_10_earnings = movie_gross_df.sort_values(by=['domestic_gross', 'foreign_gross'], ascending=False).head(10)

# Create a bar plot using Seaborn
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")

# Plot the bar chart
sns.barplot(x='title', y='domestic_gross', data=top_10_earnings, color='yellow', label='Domestic Gross')
sns.barplot(x='title', y='foreign_gross', data=top_10_earnings, color='orange', label='Foreign Gross', bottom=top_10_earnings['domestic_gross'])

# Customize the chart
plt.xticks(rotation=45)
plt.xlabel('Movie Titles')
plt.ylabel('Gross Earnings')
plt.title('Top 10 Highest Earning Movies by Domestic and Foreign Gross')
plt.legend()

# Show the chart
plt.show()

# %% [markdown]
# From the graph above, we can see that
# 1. Foreign Gross Income is more than Domestic Gross Income. This is mainly because the international market is often larger than the domestic market for many countries. Other factors include localization where studios produce films with tranlations accompanied with the films inorder to reach countries that speak other languages.
# 2. Out of the top 10 movies that do well, Marvel's The Avengers has the most gross revenue. This movie franchise is in the action/adventure genre and because of its well written story, great actors and plot twists that keep viewers itching for more, it is no wonder why it is leading.
# 3. Looking at the movies appearing in this list, genres that are frequent are action/adventure/drama etc.

# %% [markdown]
# ## DATASETS 2&3

# %%
file_path = 'title.ratings.tsv.gz'
title_ratings_df = pd.read_csv(file_path, sep='\t', compression='gzip', encoding='utf-8')

# %%
title_ratings_df
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2004
# 1        tt0000002            5.8       269
# 2        tt0000003            6.5      1900
# 3        tt0000004            5.5       178
# 4        tt0000005            6.2      2685
# ...            ...            ...       ...
# 1365199  tt9916730            7.6        11
# 1365200  tt9916766            7.0        22
# 1365201  tt9916778            7.2        36
# 1365202  tt9916840            8.8         6
# 1365203  tt9916880            8.2         6
#
# [1365204 rows x 3 columns]

# %% [markdown]
# As seen above, we start with 1365204 rows with 3 columns, where tconst column is a unique identifier for a certain film, with the averageRating being weighted average of all the individual user ratings and, the numVotes being the number of votes the title has received.
# The averageRating column has a scale from 1-10 while the numvotes column has no range.

# %%
title_ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1365204 entries, 0 to 1365203
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1365204 non-null  object
#  1   averageRating  1365204 non-null  float64
#  2   numVotes       1365204 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 31.2+ MB

# %% [markdown]
# We can see that there is one float type, one integer type and one object type.

# %%
title_ratings_df.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2004
# 1  tt0000002            5.8       269
# 2  tt0000003            6.5      1900
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2685

# %%
title_ratings_df.tail()
# Out:
#             tconst  averageRating  numVotes
# 1365199  tt9916730            7.6        11
# 1365200  tt9916766            7.0        22
# 1365201  tt9916778            7.2        36
# 1365202  tt9916840            8.8         6
# 1365203  tt9916880            8.2         6

# %%
title_ratings_df.isna().sum()
# Out:
# tconst           0
# averageRating    0
# numVotes         0
# dtype: int64

# %%
title_ratings_df
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2004
# 1        tt0000002            5.8       269
# 2        tt0000003            6.5      1900
# 3        tt0000004            5.5       178
# 4        tt0000005            6.2      2685
# ...            ...            ...       ...
# 1365199  tt9916730            7.6        11
# 1365200  tt9916766            7.0        22
# 1365201  tt9916778            7.2        36
# 1365202  tt9916840            8.8         6
# 1365203  tt9916880            8.2         6
#
# [1365204 rows x 3 columns]

# %% [markdown]
# This data set does not contain any missing values and therefore we shall proceed with the next dataframe.

# %%
file_path = 'title.basics.tsv.gz'


title_basics_df = pd.read_csv(file_path, sep='\t', compression='gzip', encoding='utf-8', low_memory=False)

# %%
title_basics_df
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10277308  tt9916848  tvEpisode              Episode #3.17
# 10277309  tt9916850  tvEpisode              Episode #3.19
# 10277310  tt9916852  tvEpisode              Episode #3.20
# 10277311  tt9916856      short                   The Wind
# 10277312  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# 2                    Pauvre Pierrot       0      1892      \N              4
# 3                       Un bon bock       0      1892      \N             12
# 4                  Blacksmith Scene       0      1893      \N              1
# ...                             ...     ...       ...     ...            ...
# 10277308              Episode #3.17       0      2009      \N             \N
# 10277309              Episode #3.19       0      2010      \N             \N
# 10277310              Episode #3.20       0      2010      \N             \N
# 10277311                   The Wind       0      2015      \N             27
# 10277312  Horrid Henry Knows It All       0      2014      \N             10
#
#                               genres
# 0                  Documentary,Short
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                       Comedy,Short
# ...                              ...
# 10277308         Action,Drama,Family
# 10277309         Action,Drama,Family
# 10277310         Action,Drama,Family
# 10277311                       Short
# 10277312  Adventure,Animation,Comedy
#
# [10277313 rows x 9 columns]

# %% [markdown]
# This dataset has 10277313 rows and 9 columns. We can see that this dataset also contains a similar column like our previous dataset(tsonst). With this, we can combine both columns for further analysis. The primaryTitle is what the movie is famously known as, while the originalTitle is what the movie was initially called by its producers.

# %%
title_basics_df.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
title_basics_df.tail()
# Out:
#              tconst  titleType               primaryTitle  \
# 10277308  tt9916848  tvEpisode              Episode #3.17
# 10277309  tt9916850  tvEpisode              Episode #3.19
# 10277310  tt9916852  tvEpisode              Episode #3.20
# 10277311  tt9916856      short                   The Wind
# 10277312  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 10277308              Episode #3.17       0      2009      \N             \N
# 10277309              Episode #3.19       0      2010      \N             \N
# 10277310              Episode #3.20       0      2010      \N             \N
# 10277311                   The Wind       0      2015      \N             27
# 10277312  Horrid Henry Knows It All       0      2014      \N             10
#
#                               genres
# 10277308         Action,Drama,Family
# 10277309         Action,Drama,Family
# 10277310         Action,Drama,Family
# 10277311                       Short
# 10277312  Adventure,Animation,Comedy

# %%
title_basics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10277313 entries, 0 to 10277312
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 705.7+ MB

# %%
title_basics_df.isna().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      11
# originalTitle     11
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres            18
# dtype: int64

# %% [markdown]
# Before I get into the missing values, I will join the 2 datasets since they contain the same alphanumeric unique identifier of the title through concatenation so that I can work on it as one datframe for further analysis.
# 1. Set the tconst column as the index column for both dataframes.
# 2. Join using inner join.

# %%
title_ratings_df.set_index('tconst', inplace=True)
title_ratings_df.head()
# Out:
#            averageRating  numVotes
# tconst
# tt0000001            5.7      2004
# tt0000002            5.8       269
# tt0000003            6.5      1900
# tt0000004            5.5       178
# tt0000005            6.2      2685

# %%
title_basics_df.set_index('tconst', inplace=True)
title_basics_df.head()
# Out:
#           titleType            primaryTitle           originalTitle isAdult  \
# tconst
# tt0000001     short              Carmencita              Carmencita       0
# tt0000002     short  Le clown et ses chiens  Le clown et ses chiens       0
# tt0000003     short          Pauvre Pierrot          Pauvre Pierrot       0
# tt0000004     short             Un bon bock             Un bon bock       0
# tt0000005     short        Blacksmith Scene        Blacksmith Scene       0
#
#           startYear endYear runtimeMinutes                    genres
# tconst
# tt0000001      1894      \N              1         Documentary,Short
# tt0000002      1892      \N              5           Animation,Short
# tt0000003      1892      \N              4  Animation,Comedy,Romance
# tt0000004      1892      \N             12           Animation,Short
# tt0000005      1893      \N              1              Comedy,Short

# %% [markdown]
# Now that I have the tables loaded correctly, I am going to join title_basics_df with title_ratings_df using the built-in .join() method on the title_basics_df object.

# %%
title_basics_with_ratings_df = title_basics_df.join(title_ratings_df, how='inner')
title_basics_with_ratings_df
# Out:
#            titleType                primaryTitle               originalTitle  \
# tconst
# tt0000001      short                  Carmencita                  Carmencita
# tt0000002      short      Le clown et ses chiens      Le clown et ses chiens
# tt0000003      short              Pauvre Pierrot              Pauvre Pierrot
# tt0000004      short                 Un bon bock                 Un bon bock
# tt0000005      short            Blacksmith Scene            Blacksmith Scene
# ...              ...                         ...                         ...
# tt9916730      movie                      6 Gunn                      6 Gunn
# tt9916766  tvEpisode              Episode #10.15              Episode #10.15
# tt9916778  tvEpisode                      Escape                      Escape
# tt9916840  tvEpisode  Horrid Henry's Comic Caper  Horrid Henry's Comic Caper
# tt9916880  tvEpisode   Horrid Henry Knows It All   Horrid Henry Knows It All
#
#           isAdult startYear endYear runtimeMinutes  \
# tconst
# tt0000001       0      1894      \N              1
# tt0000002       0      1892      \N              5
# tt0000003       0      1892      \N              4
# tt0000004       0      1892      \N             12
# tt0000005       0      1893      \N              1
# ...           ...       ...     ...            ...
# tt9916730       0      2017      \N            116
# tt9916766       0      2019      \N             43
# tt9916778       0      2019      \N             \N
# tt9916840       0      2014      \N             11
# tt9916880       0      2014      \N             10
#
#                                 genres  averageRating  numVotes
# tconst
# tt0000001            Documentary,Short            5.7      2004
# tt0000002              Animation,Short            5.8       269
# tt0000003     Animation,Comedy,Romance            6.5      1900
# tt0000004              Animation,Short            5.5       178
# tt0000005                 Comedy,Short            6.2      2685
# ...                                ...            ...       ...
# tt9916730                        Drama            7.6        11
# tt9916766  Family,Game-Show,Reality-TV            7.0        22
# tt9916778          Crime,Drama,Mystery            7.2        36
# tt9916840   Adventure,Animation,Comedy            8.8         6
# tt9916880   Adventure,Animation,Comedy            8.2         6
#
# [1365204 rows x 10 columns]

# %% [markdown]
# After joining both tables, you will note that the rows are 1365204 because from both dataframes, only 1365204 records are in both tables with the same unique identifier. I will proceed to cleaning this dataframe now.

# %%
title_basics_with_ratings_df.isna().sum()
# Out:
# titleType         0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# startYear         0
# endYear           0
# runtimeMinutes    0
# genres            3
# averageRating     0
# numVotes          0
# dtype: int64

# %%
missing_rows = title_basics_with_ratings_df[title_basics_with_ratings_df['genres'].isna()]
print(missing_rows)
len(missing_rows)
# Out:
#             titleType                                       primaryTitle  \
# tconst
# tt12149332  tvEpisode  Jeopardy! College Championship Semifinal Game ...
# tt28535095  tvEpisode         I'm into Sharif Boys\tI'm into Sharif Boys
# tt3984412   tvEpisode  I'm Not Going to Come Last, I'm Just Going to ...
#
#            originalTitle isAdult startYear endYear        runtimeMinutes  \
# tconst
# tt12149332             0    2020        \N      \N       Game-Show,Short
# tt28535095             0    2023        \N      \N            Reality-TV
# tt3984412              0    2014        \N      \N  Game-Show,Reality-TV
#
#            genres  averageRating  numVotes
# tconst
# tt12149332    NaN            6.9         8
# tt28535095    NaN            2.7         6
# tt3984412     NaN            8.3         6
# 3

# %% [markdown]
# Upon further inspection, the three primary title categories with no genre to them do not belong to any movie genre as they are not movies, and so proceeding without them will not affect our analysis in any way.

# %%
# Delete rows with missing data in the 'genre' column
title_basics_with_ratings_df.dropna(subset=['genres'], inplace=True)

# Print the DataFrame after removing rows with missing data
print(title_basics_with_ratings_df)
# Out:
#            titleType                primaryTitle               originalTitle  \
# tconst
# tt0000001      short                  Carmencita                  Carmencita
# tt0000002      short      Le clown et ses chiens      Le clown et ses chiens
# tt0000003      short              Pauvre Pierrot              Pauvre Pierrot
# tt0000004      short                 Un bon bock                 Un bon bock
# tt0000005      short            Blacksmith Scene            Blacksmith Scene
# ...              ...                         ...                         ...
# tt9916730      movie                      6 Gunn                      6 Gunn
# tt9916766  tvEpisode              Episode #10.15              Episode #10.15
# tt9916778  tvEpisode                      Escape                      Escape
# tt9916840  tvEpisode  Horrid Henry's Comic Caper  Horrid Henry's Comic Caper
# tt9916880  tvEpisode   Horrid Henry Knows It All   Horrid Henry Knows It All
#
#           isAdult startYear endYear runtimeMinutes  \
# tconst
# tt0000001       0      1894      \N              1
# tt0000002       0      1892      \N              5
# tt0000003       0      1892      \N              4
# tt0000004       0      1892      \N             12
# tt0000005       0      1893      \N              1
# ...           ...       ...     ...            ...
# tt9916730       0      2017      \N            116
# tt9916766       0      2019      \N             43
# tt9916778       0      2019      \N             \N
# tt9916840       0      2014      \N             11
# tt9916880       0      2014      \N             10
#
#                                 genres  averageRating  numVotes
# tconst
# tt0000001            Documentary,Short            5.7      2004
# tt0000002              Animation,Short            5.8       269
# tt0000003     Animation,Comedy,Romance            6.5      1900
# tt0000004              Animation,Short            5.5       178
# tt0000005                 Comedy,Short            6.2      2685
# ...                                ...            ...       ...
# tt9916730                        Drama            7.6        11
# tt9916766  Family,Game-Show,Reality-TV            7.0        22
# tt9916778          Crime,Drama,Mystery            7.2        36
# tt9916840   Adventure,Animation,Comedy            8.8         6
# tt9916880   Adventure,Animation,Comedy            8.2         6
#
# [1365201 rows x 10 columns]

# %%
title_basics_with_ratings_df.isna().sum()
# Out:
# titleType         0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# startYear         0
# endYear           0
# runtimeMinutes    0
# genres            0
# averageRating     0
# numVotes          0
# dtype: int64

# %% [markdown]
# Now that all missing values have been dealt with, I will filter out the movies from the titleType column then proceed to delete the duplicate primaryTitles.

# %%
title_basics_with_ratings_df.head()
# Out:
#           titleType            primaryTitle           originalTitle isAdult  \
# tconst
# tt0000001     short              Carmencita              Carmencita       0
# tt0000002     short  Le clown et ses chiens  Le clown et ses chiens       0
# tt0000003     short          Pauvre Pierrot          Pauvre Pierrot       0
# tt0000004     short             Un bon bock             Un bon bock       0
# tt0000005     short        Blacksmith Scene        Blacksmith Scene       0
#
#           startYear endYear runtimeMinutes                    genres  \
# tconst
# tt0000001      1894      \N              1         Documentary,Short
# tt0000002      1892      \N              5           Animation,Short
# tt0000003      1892      \N              4  Animation,Comedy,Romance
# tt0000004      1892      \N             12           Animation,Short
# tt0000005      1893      \N              1              Comedy,Short
#
#            averageRating  numVotes
# tconst
# tt0000001            5.7      2004
# tt0000002            5.8       269
# tt0000003            6.5      1900
# tt0000004            5.5       178
# tt0000005            6.2      2685

# %%
# Filter rows where 'titleType' is 'movie'
filtered_df = title_basics_with_ratings_df[title_basics_with_ratings_df['titleType'] == 'movie']

# %%
filtered_df
# Out:
#           titleType                   primaryTitle  \
# tconst
# tt0000009     movie                     Miss Jerry
# tt0000147     movie  The Corbett-Fitzsimmons Fight
# tt0000502     movie                       Bohemios
# tt0000574     movie    The Story of the Kelly Gang
# tt0000591     movie               The Prodigal Son
# ...             ...                            ...
# tt9916270     movie       Il talento del calabrone
# tt9916362     movie                          Coven
# tt9916428     movie            The Secret of China
# tt9916538     movie            Kuambil Lagi Hatiku
# tt9916730     movie                         6 Gunn
#
#                            originalTitle isAdult startYear endYear  \
# tconst
# tt0000009                     Miss Jerry       0      1894      \N
# tt0000147  The Corbett-Fitzsimmons Fight       0      1897      \N
# tt0000502                       Bohemios       0      1905      \N
# tt0000574    The Story of the Kelly Gang       0      1906      \N
# tt0000591              L'enfant prodigue       0      1907      \N
# ...                                  ...     ...       ...     ...
# tt9916270       Il talento del calabrone       0      2020      \N
# tt9916362                       Akelarre       0      2020      \N
# tt9916428   Hong xing zhao yao Zhong guo       0      2019      \N
# tt9916538            Kuambil Lagi Hatiku       0      2019      \N
# tt9916730                         6 Gunn       0      2017      \N
#
#           runtimeMinutes                      genres  averageRating  numVotes
# tconst
# tt0000009             45                     Romance            5.3       207
# tt0000147            100      Documentary,News,Sport            5.3       484
# tt0000502            100                          \N            4.1        15
# tt0000574             70  Action,Adventure,Biography            6.0       854
# tt0000591             90                       Drama            5.0        21
# ...                  ...                         ...            ...       ...
# tt9916270             84                    Thriller            5.8      1446
# tt9916362             92               Drama,History            6.4      5592
# tt9916428             \N       Adventure,History,War            3.5        17
# tt9916538            123                       Drama            8.6         7
# tt9916730            116                       Drama            7.6        11
#
# [299271 rows x 10 columns]

# %%
title_basics_with_ratings_df = title_basics_with_ratings_df[title_basics_with_ratings_df['titleType'] == 'movie']

# %% [markdown]
# The above function will maintain only titletypes that are movies, which is the main focus of our business problem.

# %%
title_basics_with_ratings_df
# Out:
#           titleType                   primaryTitle  \
# tconst
# tt0000009     movie                     Miss Jerry
# tt0000147     movie  The Corbett-Fitzsimmons Fight
# tt0000502     movie                       Bohemios
# tt0000574     movie    The Story of the Kelly Gang
# tt0000591     movie               The Prodigal Son
# ...             ...                            ...
# tt9916270     movie       Il talento del calabrone
# tt9916362     movie                          Coven
# tt9916428     movie            The Secret of China
# tt9916538     movie            Kuambil Lagi Hatiku
# tt9916730     movie                         6 Gunn
#
#                            originalTitle isAdult startYear endYear  \
# tconst
# tt0000009                     Miss Jerry       0      1894      \N
# tt0000147  The Corbett-Fitzsimmons Fight       0      1897      \N
# tt0000502                       Bohemios       0      1905      \N
# tt0000574    The Story of the Kelly Gang       0      1906      \N
# tt0000591              L'enfant prodigue       0      1907      \N
# ...                                  ...     ...       ...     ...
# tt9916270       Il talento del calabrone       0      2020      \N
# tt9916362                       Akelarre       0      2020      \N
# tt9916428   Hong xing zhao yao Zhong guo       0      2019      \N
# tt9916538            Kuambil Lagi Hatiku       0      2019      \N
# tt9916730                         6 Gunn       0      2017      \N
#
#           runtimeMinutes                      genres  averageRating  numVotes
# tconst
# tt0000009             45                     Romance            5.3       207
# tt0000147            100      Documentary,News,Sport            5.3       484
# tt0000502            100                          \N            4.1        15
# tt0000574             70  Action,Adventure,Biography            6.0       854
# tt0000591             90                       Drama            5.0        21
# ...                  ...                         ...            ...       ...
# tt9916270             84                    Thriller            5.8      1446
# tt9916362             92               Drama,History            6.4      5592
# tt9916428             \N       Adventure,History,War            3.5        17
# tt9916538            123                       Drama            8.6         7
# tt9916730            116                       Drama            7.6        11
#
# [299271 rows x 10 columns]

# %%
title_basics_with_ratings_df = title_basics_with_ratings_df.drop_duplicates(subset='primaryTitle')

# %%
title_basics_with_ratings_df
# Out:
#           titleType                   primaryTitle  \
# tconst
# tt0000009     movie                     Miss Jerry
# tt0000147     movie  The Corbett-Fitzsimmons Fight
# tt0000502     movie                       Bohemios
# tt0000574     movie    The Story of the Kelly Gang
# tt0000591     movie               The Prodigal Son
# ...             ...                            ...
# tt9916190     movie                      Safeguard
# tt9916270     movie       Il talento del calabrone
# tt9916428     movie            The Secret of China
# tt9916538     movie            Kuambil Lagi Hatiku
# tt9916730     movie                         6 Gunn
#
#                            originalTitle isAdult startYear endYear  \
# tconst
# tt0000009                     Miss Jerry       0      1894      \N
# tt0000147  The Corbett-Fitzsimmons Fight       0      1897      \N
# tt0000502                       Bohemios       0      1905      \N
# tt0000574    The Story of the Kelly Gang       0      1906      \N
# tt0000591              L'enfant prodigue       0      1907      \N
# ...                                  ...     ...       ...     ...
# tt9916190                      Safeguard       0      2020      \N
# tt9916270       Il talento del calabrone       0      2020      \N
# tt9916428   Hong xing zhao yao Zhong guo       0      2019      \N
# tt9916538            Kuambil Lagi Hatiku       0      2019      \N
# tt9916730                         6 Gunn       0      2017      \N
#
#           runtimeMinutes                      genres  averageRating  numVotes
# tconst
# tt0000009             45                     Romance            5.3       207
# tt0000147            100      Documentary,News,Sport            5.3       484
# tt0000502            100                          \N            4.1        15
# tt0000574             70  Action,Adventure,Biography            6.0       854
# tt0000591             90                       Drama            5.0        21
# ...                  ...                         ...            ...       ...
# tt9916190             95   Action,Adventure,Thriller            3.7       245
# tt9916270             84                    Thriller            5.8      1446
# tt9916428             \N       Adventure,History,War            3.5        17
# tt9916538            123                       Drama            8.6         7
# tt9916730            116                       Drama            7.6        11
#
# [265850 rows x 10 columns]

# %% [markdown]
# Before proceeding to the gross earnings from the movies, I will inspect the relationship between
# 1. Genres and averageRating
# 2. Genres and numVotes

# %%
unique_genres = title_basics_with_ratings_df['genres'].unique()

# Print all unique genres
for genre in unique_genres:
    print(genre)
# Out:
# Romance
# Documentary,News,Sport
# \N
# Action,Adventure,Biography
# Drama
# Adventure,Fantasy
# Comedy
# Drama,War
# Crime
# Drama,Romance
# Adventure,Drama
# Biography,Drama,Family
# Drama,History
# War
# Biography,Drama,History
# Sci-Fi
# Adventure,Drama,Fantasy
# Biography,Drama
# Documentary,War
# Biography,Drama,Romance
# History,War
# Action,Drama,Thriller
# Crime,Thriller
# Adventure
# Drama,Thriller
# Western
# Crime,Drama,Romance
# Crime,Drama
# Documentary
# Comedy,Fantasy
# Adventure,Drama,Romance
# Crime,Drama,Mystery
# Biography
# Drama,Fantasy,Horror
# Action,Adventure
# Comedy,Crime
# Adventure,Comedy
# Documentary,Western
# Crime,Drama,Horror
# Adventure,Biography,Western
# Adventure,Drama,History
# Drama,Fantasy
# Drama,Music,Western
# Action
# Adventure,Horror
# Horror
# Drama,Mystery
# Adventure,Comedy,Family
# Crime,Horror,Mystery
# History,Western
# Action,Adventure,Drama
# Adventure,Mystery,Romance
# Fantasy
# Action,Adventure,Romance
# Drama,Western
# Action,Drama,Romance
# Comedy,Drama
# Comedy,Drama,Romance
# Adventure,Mystery
# Documentary,Sport
# Comedy,Thriller
# Adventure,Family,Fantasy
# Adventure,Comedy,Drama
# Drama,History,War
# Drama,Sci-Fi
# Drama,Romance,War
# Comedy,Western
# Adventure,Romance
# Comedy,Romance
# Adventure,Crime,Drama
# Romance,Western
# Drama,History,Romance
# Adventure,Comedy,Western
# Drama,Horror,Sci-Fi
# Action,Adventure,Crime
# Adventure,Drama,Mystery
# Drama,Horror
# Adventure,Romance,Western
# Biography,Crime,Drama
# Adventure,Crime,Thriller
# Action,Adventure,Comedy
# Action,Adventure,Sci-Fi
# Action,Drama
# Adventure,Comedy,Romance
# Adventure,History
# Horror,Mystery
# Action,Biography,Western
# Adventure,Western
# Comedy,Crime,Drama
# Comedy,Sport
# Horror,Sci-Fi
# Adventure,Crime
# Action,Adventure,War
# Action,Drama,War
# Action,Comedy,Romance
# Comedy,Sci-Fi
# Comedy,Drama,Mystery
# Action,Comedy,Drama
# Adventure,Romance,Thriller
# Crime,Mystery
# Adventure,Drama,Western
# Fantasy,Romance
# History
# Drama,Mystery,Romance
# Animation,Comedy,Drama
# Drama,Family,Fantasy
# Fantasy,Thriller
# Biography,Western
# Action,Romance,Western
# Adventure,Fantasy,Sci-Fi
# Adventure,Family
# Drama,Horror,Mystery
# Drama,History,Western
# Adventure,War
# Comedy,Drama,Family
# Adventure,Crime,Romance
# Comedy,Mystery,Thriller
# Drama,Fantasy,Sci-Fi
# Comedy,Romance,Western
# History,Romance
# Documentary,History,War
# Mystery
# Adventure,Comedy,Crime
# Animation
# Family,Fantasy
# Drama,Thriller,War
# Drama,Family,Romance
# Animation,Comedy
# Adventure,Fantasy,Romance
# Action,Western
# Comedy,Drama,War
# Music
# Drama,Romance,Thriller
# Crime,Drama,History
# Action,Crime,Thriller
# Action,Drama,Western
# Drama,Sport
# Crime,Western
# Comedy,Crime,Western
# Drama,Romance,Western
# Romance,Thriller
# Drama,Horror,War
# Comedy,Drama,Western
# Horror,Mystery,Thriller
# Adventure,Horror,Romance
# Action,Adventure,Mystery
# Drama,History,Horror
# Comedy,Fantasy,Sci-Fi
# Comedy,Drama,Sport
# Action,Mystery,Thriller
# Fantasy,Horror,Mystery
# Adventure,Mystery,Western
# Fantasy,Sci-Fi
# Action,Adventure,Fantasy
# Adventure,Fantasy,Mystery
# Adventure,Drama,War
# Action,Crime,Drama
# Comedy,Drama,Horror
# Adventure,Sci-Fi
# Biography,Comedy,Drama
# Drama,Music,War
# Action,Adventure,Western
# Crime,Drama,Thriller
# Adventure,Documentary
# Action,Thriller
# Drama,Horror,Thriller
# Adventure,Comedy,Fantasy
# Crime,Romance,Thriller
# Action,Sport,Thriller
# Drama,Romance,Sport
# Crime,Mystery,Thriller
# Comedy,Family
# Documentary,Fantasy,Horror
# Crime,Romance
# Mystery,Sci-Fi
# Fantasy,Horror
# Comedy,Horror,Mystery
# Adventure,Mystery,Thriller
# Drama,Horror,Romance
# Action,Comedy,Sport
# Comedy,Romance,Thriller
# Action,Comedy,Thriller
# Drama,Romance,Sci-Fi
# Drama,Family
# Action,Drama,Sport
# Action,Drama,Family
# Comedy,Fantasy,Romance
# Adventure,Animation,Family
# Adventure,War,Western
# Drama,Fantasy,Romance
# Drama,History,Thriller
# Adventure,Family,Romance
# Comedy,Family,Romance
# Drama,Thriller,Western
# Comedy,Family,Musical
# Action,Drama,Sci-Fi
# Comedy,Crime,Romance
# Comedy,Romance,Sport
# Documentary,Drama
# Comedy,Drama,Fantasy
# Adventure,Family,Western
# Adventure,Drama,Horror
# Action,Comedy,Crime
# Mystery,Thriller
# Action,History,Romance
# Biography,History,Western
# Adventure,Romance,War
# Comedy,Musical
# Action,Comedy,War
# Action,Adventure,Family
# Adventure,Crime,Mystery
# Action,Drama,Fantasy
# Horror,Thriller
# Comedy,Romance,War
# Action,Crime
# Action,Drama,Mystery
# Comedy,Mystery
# Adventure,Documentary,Drama
# Adventure,Drama,Thriller
# Action,Drama,History
# Comedy,War
# Drama,Music,Musical
# Drama,Fantasy,War
# Documentary,History
# Action,Comedy
# Thriller
# Crime,Drama,Film-Noir
# Horror,Mystery,Sci-Fi
# Adventure,Mystery,War
# Musical
# Crime,Drama,Music
# Comedy,Drama,Music
# Drama,Musical
# Action,Comedy,Family
# Action,Crime,Romance
# Drama,Musical,Romance
# Comedy,Crime,Mystery
# Action,Drama,Music
# Crime,Music,Romance
# Comedy,Drama,Musical
# Documentary,Music
# Comedy,Musical,Romance
# Action,Musical,Romance
# Music,Romance,War
# Adventure,Drama,Music
# Comedy,Music
# Drama,Music,Romance
# Musical,Romance
# Drama,Mystery,Thriller
# Adventure,Romance,Sci-Fi
# Crime,Mystery,Romance
# Comedy,Musical,Western
# Music,Romance,Sport
# Biography,Drama,War
# Action,Comedy,Music
# Mystery,Romance,Western
# Comedy,Music,Romance
# Drama,Music
# Crime,Drama,War
# Drama,Musical,Mystery
# Music,Romance
# Comedy,Fantasy,Musical
# Biography,Drama,Musical
# Family,Western
# War,Western
# Drama,Family,Western
# Action,Adventure,Music
# Music,Musical,Romance
# Crime,Drama,Musical
# Adventure,Animation,Comedy
# Comedy,Mystery,Romance
# Action,Romance,Thriller
# Adventure,Comedy,Mystery
# Mystery,Romance
# Action,Adventure,Musical
# Comedy,Musical,Sport
# Adventure,Comedy,Music
# Adventure,Musical,Romance
# Drama,Family,Sport
# Comedy,Family,Fantasy
# Adventure,Drama,Family
# Adventure,Comedy,Musical
# Action,Adventure,Horror
# Comedy,History,Musical
# Comedy,Film-Noir
# Drama,Mystery,Western
# Action,Crime,Mystery
# Mystery,Sport
# Drama,Fantasy,Mystery
# Comedy,Crime,Horror
# Comedy,Crime,Musical
# Adventure,Horror,Sci-Fi
# Crime,Drama,Western
# Mystery,Western
# Crime,Film-Noir,Romance
# Adventure,Drama,Film-Noir
# Drama,Mystery,Sci-Fi
# Comedy,Horror
# Adventure,Thriller,Western
# Comedy,Horror,Sci-Fi
# Drama,Film-Noir,Romance
# History,Musical
# Comedy,Music,Mystery
# Comedy,Fantasy,Music
# Action,Drama,Horror
# Action,Crime,Music
# Film-Noir,Horror,Sci-Fi
# Action,Mystery,Romance
# Biography,Drama,Music
# Romance,Sport
# Adventure,Music,Romance
# Drama,Sci-Fi,War
# Crime,Horror
# Crime,Music,Mystery
# Music,Romance,Western
# Comedy,Drama,History
# Adventure,Family,Horror
# Biography,Music,Romance
# Comedy,Music,Musical
# Action,Crime,Family
# Comedy,Family,Mystery
# Drama,History,Music
# Comedy,Musical,Mystery
# Adventure,Crime,Horror
# Drama,Mystery,Sport
# Action,Comedy,Mystery
# Action,Crime,Western
# Biography,Comedy
# Crime,Music,Musical
# Drama,History,Musical
# Comedy,Family,Music
# Crime,Musical,Romance
# Action,Adventure,Thriller
# Biography,Drama,Western
# Adventure,Drama,Musical
# Family,Musical,Romance
# Action,Biography,Drama
# Action,Romance
# Comedy,Fantasy,Horror
# Comedy,History,Romance
# Adventure,Biography,Drama
# Comedy,Crime,Music
# Comedy,History,Mystery
# Drama,News,War
# Musical,Romance,Western
# Family,Musical
# Musical,Mystery,Romance
# Family,Sci-Fi
# Comedy,Crime,Film-Noir
# Comedy,Family,War
# Family
# Biography,Musical,Romance
# Drama,Family,Musical
# Crime,Film-Noir,Mystery
# Comedy,Crime,Family
# Crime,Drama,Sport
# Adventure,Family,Sci-Fi
# Action,Romance,Sport
# Comedy,Music,War
# Action,Drama,Musical
# Adventure,Crime,Sci-Fi
# Action,Music,Romance
# Drama,History,Mystery
# Adventure,History,Romance
# Mystery,Romance,Sport
# Crime,Mystery,Sci-Fi
# Adventure,Music,Musical
# Comedy,Thriller,War
# Musical,Western
# Crime,Film-Noir,Thriller
# Comedy,History
# Crime,Musical
# Action,Adventure,History
# Drama,Film-Noir,Mystery
# Action,Music,Western
# Adventure,Biography,Romance
# Comedy,Musical,War
# Comedy,Music,Sport
# Biography,War
# Drama,Fantasy,Musical
# Musical,Romance,Sport
# Romance,Sci-Fi
# Drama,Film-Noir
# Action,History
# Biography,Drama,Sport
# Crime,Film-Noir
# Comedy,Crime,Sport
# Biography,Music,Musical
# Adventure,Crime,Family
# Adventure,Comedy,War
# Crime,Horror,Sci-Fi
# History,War,Western
# Adventure,Thriller
# Action,Family,Horror
# Musical,Romance,Thriller
# Crime,Sci-Fi
# Drama,Music,Mystery
# Thriller,War
# Biography,Comedy,Music
# Drama,Family,Music
# Crime,Drama,Family
# Action,Music
# Animation,Family,Fantasy
# Biography,Documentary,Drama
# Romance,Thriller,War
# Sport,Thriller
# Fantasy,Mystery
# Romance,War
# Comedy,Romance,Sci-Fi
# Comedy,Crime,Thriller
# Action,Music,Sci-Fi
# Adventure,Fantasy,Horror
# Drama,War,Western
# Musical,Romance,War
# History,Music,Romance
# Adventure,Animation,Drama
# Action,Comedy,Musical
# Animation,Comedy,Family
# Adventure,Comedy,Horror
# Mystery,Thriller,War
# Biography,Musical
# Drama,Mystery,War
# Action,Documentary
# Film-Noir,Mystery,Thriller
# Comedy,Fantasy,Mystery
# Action,Crime,Musical
# Fantasy,Horror,Thriller
# Biography,History
# Horror,Mystery,Romance
# Comedy,Drama,Film-Noir
# Action,Adventure,Documentary
# Drama,Film-Noir,Thriller
# Film-Noir,Mystery,Romance
# Mystery,Romance,Thriller
# Drama,Musical,Western
# History,Romance,Sci-Fi
# Film-Noir,Horror,Mystery
# Action,Documentary,Drama
# Film-Noir,Mystery
# Fantasy,Horror,Sci-Fi
# Adventure,Biography,War
# Film-Noir,Horror,Thriller
# Horror,Sci-Fi,Thriller
# Action,War
# Musical,War
# Action,Crime,Film-Noir
# Drama,Horror,Music
# Film-Noir,Thriller
# Biography,Drama,Mystery
# Animation,Documentary,History
# Crime,Horror,Thriller
# Comedy,Horror,Romance
# Film-Noir,Romance,Thriller
# Drama,Fantasy,Thriller
# Drama,Film-Noir,Horror
# Mystery,Romance,War
# Action,Fantasy,Horror
# Adventure,Comedy,Film-Noir
# Adventure,Crime,Western
# Drama,Horror,Western
# Adventure,Film-Noir,Mystery
# Adventure,Animation,Musical
# Adventure,Comedy,Thriller
# Action,Crime,Horror
# Action,Sci-Fi
# Comedy,Music,Western
# Music,Musical
# Drama,Musical,War
# Fantasy,Musical
# Fantasy,Musical,Romance
# Comedy,Drama,Thriller
# Adventure,Crime,Film-Noir
# Comedy,Sci-Fi,War
# Adventure,Film-Noir,Romance
# Animation,Fantasy,Romance
# Drama,Musical,Thriller
# Drama,Film-Noir,Music
# Comedy,Fantasy,History
# Comedy,Film-Noir,Mystery
# Family,Fantasy,Musical
# Action,Comedy,Fantasy
# Adventure,Comedy,Sport
# Mystery,Sci-Fi,Thriller
# Adventure,Family,Mystery
# Crime,Drama,Fantasy
# Animation,Comedy,Romance
# Action,Biography,Crime
# Biography,Crime,History
# Comedy,Documentary
# Comedy,Family,Western
# Comedy,History,War
# Adventure,Documentary,Thriller
# Drama,Film-Noir,Sport
# Drama,Fantasy,Film-Noir
# Adventure,Animation
# Action,Crime,Sci-Fi
# Comedy,History,Music
# Comedy,Family,Sci-Fi
# Biography,Music
# Comedy,Family,Horror
# History,Romance,Thriller
# Biography,Documentary
# Drama,Family,History
# Animation,Drama,Family
# Drama,Sport,Thriller
# Adventure,Drama,Sci-Fi
# Sci-Fi,Thriller
# Comedy,Family,Sport
# Family,Fantasy,Romance
# Biography,Comedy,Musical
# Drama,Sport,War
# Animation,Musical
# Family,Romance
# Horror,Romance,Sci-Fi
# Action,Family,Sci-Fi
# Action,Drama,Film-Noir
# Crime,Horror,Romance
# Fantasy,Music,Musical
# Biography,History,Music
# Action,Sci-Fi,Thriller
# Comedy,Crime,Fantasy
# Animation,Comedy,Fantasy
# Adventure,Horror,Mystery
# Film-Noir,Western
# Biography,Family,Musical
# Comedy,Drama,Sci-Fi
# Animation,Fantasy,Musical
# Thriller,War,Western
# Adventure,Sci-Fi,War
# Family,Fantasy,Music
# History,Musical,Romance
# Drama,Sport,Western
# Crime,History,Musical
# Horror,Romance
# Crime,Family,Mystery
# Biography,Drama,Film-Noir
# Documentary,Family
# History,Romance,Western
# Adventure,Biography,History
# Adventure,Documentary,Fantasy
# Animation,Fantasy
# Drama,Fantasy,Music
# Romance,War,Western
# Adventure,History,War
# Crime,Drama,Sci-Fi
# Adventure,Family,History
# Action,Comedy,Western
# Comedy,Fantasy,Sport
# Action,Fantasy,Sci-Fi
# Animation,Drama
# Comedy,Musical,Sci-Fi
# History,Romance,War
# Documentary,Musical
# History,Thriller
# Crime,Sci-Fi,Thriller
# Action,Horror,Sci-Fi
# Film-Noir,Horror
# Adventure,Family,Musical
# Biography,Documentary,History
# Crime,Family
# Comedy,Documentary,Music
# Crime,Romance,Western
# Biography,Drama,Thriller
# Adventure,Crime,Fantasy
# Crime,War
# Family,Horror,Sci-Fi
# Adventure,Fantasy,History
# Action,Romance,War
# Adventure,Family,War
# Fantasy,Musical,Mystery
# Comedy,Music,Thriller
# Crime,Fantasy,Horror
# Horror,Sci-Fi,Western
# Biography,Crime,Film-Noir
# Musical,Thriller
# Horror,Mystery,Western
# Documentary,Drama,Romance
# Action,Mystery
# Biography,Sci-Fi
# Adventure,Musical
# Documentary,Romance
# Action,Horror,Romance
# Documentary,Drama,War
# Adventure,Sci-Fi,Thriller
# Horror,Western
# Action,Biography,History
# Family,War
# Documentary,History,News
# Biography,Fantasy
# Comedy,Horror,Thriller
# Adventure,Comedy,Documentary
# Family,Fantasy,History
# Animation,Family
# Animation,Documentary
# Comedy,Sci-Fi,Thriller
# Action,Horror
# Adventure,History,Mystery
# Mystery,Thriller,Western
# Musical,Mystery,Thriller
# Action,Fantasy
# Fantasy,Romance,Sci-Fi
# Action,Adventure,Animation
# Adventure,Animation,Biography
# Biography,Sport
# Documentary,Thriller
# Comedy,Documentary,Drama
# Adventure,Comedy,History
# Drama,Fantasy,History
# Fantasy,Mystery,Western
# Comedy,War,Western
# Adventure,Biography,Comedy
# Biography,Documentary,War
# Horror,Musical
# Adventure,Fantasy,War
# Documentary,Horror
# Fantasy,Music,Romance
# Documentary,History,Music
# Biography,Crime,Thriller
# Action,Horror,Mystery
# Family,Sport
# Adventure,Animation,Fantasy
# Adventure,Biography
# Biography,Drama,Horror
# Adventure,Comedy,Sci-Fi
# Action,Thriller,War
# Adventure,Crime,History
# Comedy,Crime,Sci-Fi
# Adventure,Biography,Family
# Comedy,Horror,Musical
# Adventure,Animation,Sci-Fi
# Comedy,Music,Sci-Fi
# Action,Comedy,Horror
# Comedy,Fantasy,Western
# Action,Sport
# Comedy,Documentary,Family
# Action,Family,Fantasy
# Action,Animation,History
# Action,Comedy,Sci-Fi
# Crime,Musical,Mystery
# Fantasy,Sci-Fi,Thriller
# Biography,History,Romance
# Fantasy,Music
# Documentary,History,Sport
# Action,Thriller,Western
# Biography,Comedy,Documentary
# Animation,Comedy,Musical
# Biography,Documentary,Music
# Action,History,War
# Adventure,Musical,Mystery
# Family,Music
# Biography,Comedy,History
# Sport
# Biography,Horror
# Drama,Fantasy,Sport
# Adventure,Biography,Crime
# Adult
# Animation,Drama,Sport
# Adult,Fantasy,Horror
# Thriller,Western
# Crime,Thriller,Western
# Musical,Sci-Fi
# Documentary,Family,Sport
# Documentary,Music,Thriller
# Adventure,Fantasy,Musical
# Adult,Documentary
# Adult,Comedy,Drama
# Adult,Drama
# Adult,Comedy
# Adventure,Family,Sport
# Comedy,Documentary,Sport
# Drama,Sci-Fi,Thriller
# Fantasy,Mystery,Thriller
# Biography,Romance
# Adult,Adventure,Comedy
# Action,Animation,Family
# Adventure,Crime,Musical
# Action,Adult,Western
# Documentary,Drama,Music
# Biography,Crime,Documentary
# Adult,Horror
# Adventure,Horror,Thriller
# Adventure,Documentary,Romance
# Horror,Romance,Thriller
# Action,Adult,Drama
# Family,History,Sci-Fi
# Action,Musical,Thriller
# Crime,Horror,Musical
# Action,Documentary,Sport
# Family,Fantasy,Mystery
# Fantasy,Horror,Romance
# Horror,Thriller,Western
# Action,Biography,Comedy
# Adventure,Animation,Crime
# Animation,Documentary,Drama
# Adventure,History,Musical
# Adult,Drama,Fantasy
# Biography,Documentary,Sport
# Documentary,Drama,Fantasy
# Animation,Sci-Fi
# Adult,Drama,Romance
# Adult,Crime,Horror
# Adult,Comedy,Sci-Fi
# Animation,Drama,Fantasy
# Action,Animation,Comedy
# Documentary,Mystery
# Comedy,Documentary,Horror
# Adult,Comedy,Romance
# Adult,Adventure
# Adult,Western
# Music,Sci-Fi
# Documentary,Family,Musical
# Adult,Animation,Drama
# Documentary,History,Reality-TV
# Family,Fantasy,Sci-Fi
# Adult,Horror,Thriller
# Animation,Documentary,Family
# Adult,Biography,Documentary
# Animation,Comedy,Music
# Biography,Comedy,Crime
# Adult,Crime
# Adult,Crime,Drama
# Fantasy,Western
# Action,Sci-Fi,Sport
# Adult,Drama,Thriller
# Adult,Comedy,Horror
# Adult,Comedy,Fantasy
# Horror,Thriller,War
# Adult,Drama,Horror
# Adult,Crime,Mystery
# Horror,War
# Action,Horror,Thriller
# Adult,Comedy,Musical
# Comedy,Mystery,Sci-Fi
# Documentary,Horror,Music
# Adult,Romance
# Documentary,Sci-Fi
# Fantasy,Musical,Sci-Fi
# Adult,Adventure,Drama
# Comedy,Crime,History
# Adult,Fantasy
# Adult,Thriller
# Comedy,Documentary,Romance
# Documentary,Mystery,Sci-Fi
# Adult,Drama,War
# Biography,History,War
# Adult,Drama,Musical
# Crime,Mystery,Western
# Adult,Mystery
# Adult,Comedy,Western
# Crime,Documentary
# Crime,History,Mystery
# Adult,Comedy,Crime
# Adventure,Crime,Sport
# Documentary,Drama,Western
# Family,Mystery
# Drama,Sci-Fi,Sport
# Documentary,Drama,History
# Adventure,Mystery,Sci-Fi
# Fantasy,History,Romance
# Fantasy,Mystery,Sci-Fi
# Music,Musical,Sci-Fi
# Action,Comedy,History
# Adult,Crime,Romance
# Action,Adult,Adventure
# Crime,Horror,Music
# Action,Animation,Drama
# Action,Crime,Sport
# Family,Horror,Mystery
# Drama,Family,War
# Animation,Drama,History
# Crime,Music,Thriller
# Action,Romance,Sci-Fi
# Drama,Family,Thriller
# Fantasy,Romance,Thriller
# Animation,Comedy,Crime
# Adult,Sci-Fi
# Animation,Fantasy,Music
# Action,Crime,Fantasy
# Drama,Music,Sport
# Action,Fantasy,Romance
# Comedy,Documentary,Musical
# Action,Animation,Crime
# Crime,Sport
# Animation,Biography,Drama
# Adult,Drama,Mystery
# Adult,Crime,Thriller
# Comedy,Family,History
# Adult,Drama,Music
# Horror,Sport
# Horror,Music
# Action,Fantasy,Thriller
# Fantasy,Mystery,Romance
# Documentary,Horror,Thriller
# Comedy,Horror,Music
# History,Mystery
# Action,Sci-Fi,Western
# Action,Animation,Fantasy
# Animation,Comedy,Horror
# Music,Mystery,Thriller
# Animation,Drama,War
# Adventure,Animation,Western
# Action,Crime,War
# Action,Family,Sport
# Action,Animation,Music
# Animation,Family,Romance
# Animation,Drama,Horror
# Horror,Music,Thriller
# Crime,Family,Thriller
# Animation,Drama,Sci-Fi
# Drama,Music,Sci-Fi
# Action,Horror,War
# Animation,Crime,Drama
# Drama,History,Sport
# Action,History,Thriller
# Animation,Biography,Comedy
# Animation,Comedy,Sci-Fi
# Action,Biography
# Biography,Fantasy,Mystery
# Comedy,Horror,Western
# Documentary,History,Romance
# Adult,Comedy,Mystery
# Music,Thriller
# Comedy,Fantasy,Thriller
# Adventure,Drama,Sport
# Animation,Family,Musical
# Crime,Documentary,Mystery
# Crime,Documentary,Drama
# Drama,Family,Mystery
# Action,Musical,Mystery
# Horror,Romance,Western
# Animation,Biography,Documentary
# Family,Thriller
# Documentary,Drama,Sci-Fi
# Animation,Drama,Thriller
# Action,Biography,Documentary
# Biography,Drama,Fantasy
# Action,Fantasy,History
# Action,Animation,Sci-Fi
# Action,Family
# Adventure,Documentary,Sport
# Documentary,Drama,Sport
# Biography,Documentary,Mystery
# Biography,Comedy,Romance
# Sci-Fi,Western
# Biography,Documentary,Horror
# Family,Fantasy,Horror
# Documentary,Family,Music
# Adventure,Sci-Fi,Western
# Action,Adult,Crime
# Documentary,Romance,War
# Documentary,Thriller,War
# Biography,Documentary,Romance
# Reality-TV,Thriller
# Action,Mystery,Sci-Fi
# Comedy,Family,Thriller
# Comedy,Documentary,History
# Action,Adult,Fantasy
# Adult,Adventure,Sci-Fi
# Adult,Comedy,Music
# Adventure,Sport
# Comedy,Crime,Documentary
# Adult,Horror,Mystery
# Adult,Fantasy,Romance
# Animation,Biography,History
# Animation,History
# Music,Western
# Adult,Sport
# Adult,Comedy,History
# Adventure,Documentary,News
# Biography,Crime
# Adult,Mystery,Thriller
# Adult,Adventure,Mystery
# Crime,Music
# Adult,Comedy,Thriller
# Documentary,Music,Romance
# Crime,Documentary,Fantasy
# Crime,Fantasy,Mystery
# Animation,Comedy,Western
# Adult,Animation
# Adult,Biography,Drama
# Action,Musical,War
# Action,Musical
# Adventure,History,Thriller
# Family,Fantasy,Sport
# Adult,Drama,Sport
# Animation,Comedy,Sport
# Animation,Family,Sci-Fi
# Adult,Music
# Horror,Music,Sci-Fi
# Crime,Fantasy,Musical
# Crime,Documentary,History
# Animation,News
# Drama,Musical,Sport
# Fantasy,History,Horror
# Adventure,Documentary,History
# Adult,Documentary,History
# Animation,Comedy,History
# Action,Adult
# Action,Adult,Comedy
# Crime,History
# Fantasy,History
# Action,Documentary,War
# Action,Crime,Documentary
# Adult,Biography
# Drama,Sci-Fi,Western
# Drama,Music,Thriller
# Fantasy,History,War
# Adult,Drama,History
# Animation,Documentary,War
# Adult,Comedy,Sport
# Adult,Romance,Western
# Adult,Drama,Western
# Adult,Comedy,War
# Documentary,Music,Sport
# Adult,Crime,Talk-Show
# Drama,Family,Sci-Fi
# Action,Animation
# Documentary,Fantasy,Music
# Family,Horror
# Animation,Fantasy,Sci-Fi
# History,Mystery,Thriller
# Comedy,Sport,War
# Action,Biography,Thriller
# Mystery,Romance,Sci-Fi
# Music,Mystery
# Adult,Adventure,Romance
# Action,Family,Romance
# Action,Documentary,Reality-TV
# Documentary,War,Western
# Documentary,Drama,Mystery
# Action,Crime,History
# Horror,Music,Mystery
# Comedy,Documentary,Mystery
# Music,Sci-Fi,Thriller
# Adult,Comedy,Documentary
# Romance,Sci-Fi,Thriller
# Comedy,Documentary,War
# Adult,Talk-Show
# Adult,Romance,Thriller
# Biography,Romance,War
# Family,Fantasy,Western
# Drama,Horror,Musical
# Adventure,Family,Music
# Adventure,Fantasy,Thriller
# Adventure,Documentary,Family
# Action,Animation,Horror
# Action,Musical,Western
# Crime,Fantasy
# Fantasy,Horror,Western
# Animation,Fantasy,Horror
# Adult,Adventure,Animation
# Adult,History
# Documentary,News
# Documentary,Horror,Mystery
# Adventure,Crime,War
# Action,Animation,Romance
# Biography,Crime,Horror
# Documentary,Music,Musical
# Action,Animation,Mystery
# Adventure,Animation,Romance
# Animation,Fantasy,History
# Action,Documentary,Family
# Adult,Documentary,Romance
# Adventure,Documentary,War
# Action,Comedy,Documentary
# Biography,Documentary,News
# Musical,Sci-Fi,Thriller
# Documentary,Drama,Family
# Documentary,Reality-TV
# Animation,Documentary,Fantasy
# Action,Biography,War
# Animation,Drama,Mystery
# History,Horror
# Biography,Documentary,Musical
# Action,Family,Musical
# Adult,Animation,Horror
# Documentary,Drama,Musical
# Musical,Mystery
# Action,Documentary,Fantasy
# Family,Music,Musical
# Animation,Horror,Sci-Fi
# Crime,Documentary,Thriller
# Action,Fantasy,Musical
# Action,Family,Mystery
# Adult,Animation,Comedy
# Comedy,Documentary,Sci-Fi
# Adventure,Animation,Music
# Comedy,Documentary,Reality-TV
# Animation,Drama,Romance
# Comedy,Talk-Show
# Adult,Horror,Romance
# Mystery,War
# Action,Animation,Sport
# Drama,Family,Horror
# Family,Music,Romance
# Crime,Documentary,Horror
# Animation,Biography
# Adult,Animation,Fantasy
# Fantasy,Sport
# Biography,Fantasy,History
# Adventure,Biography,Documentary
# Adult,Adventure,Crime
# Documentary,Fantasy
# Documentary,History,Horror
# Family,Mystery,Sci-Fi
# Fantasy,Horror,War
# Animation,Thriller
# Biography,Comedy,Horror
# Biography,Comedy,Sci-Fi
# Crime,Documentary,War
# Horror,Sport,Thriller
# Action,Horror,Western
# Adventure,Animation,Mystery
# Animation,Horror,Mystery
# Animation,Horror
# Animation,Music
# Animation,History,War
# Action,Fantasy,Mystery
# Biography,Documentary,Western
# Action,History,Mystery
# Documentary,History,Musical
# Documentary,History,Mystery
# Documentary,Family,Mystery
# Documentary,Music,War
# Crime,Thriller,War
# Horror,Musical,Sci-Fi
# Animation,Crime,Music
# Adventure,Music
# Crime,Documentary,News
# Adventure,Animation,History
# Drama,History,Sci-Fi
# Animation,Musical,Sport
# Family,History,Musical
# Animation,Family,Western
# History,Horror,Thriller
# Animation,Sport
# Animation,Musical,Romance
# History,Sci-Fi
# Comedy,Horror,Sport
# Biography,History,Thriller
# Fantasy,Horror,Musical
# Animation,Sci-Fi,War
# Biography,Documentary,Family
# Drama,News,Thriller
# Biography,Documentary,Reality-TV
# Biography,Family
# Documentary,Drama,Horror
# Adventure,Animation,Documentary
# News
# Comedy,Documentary,Fantasy
# Biography,Music,Mystery
# Reality-TV
# Adventure,Horror,Musical
# Documentary,Mystery,Reality-TV
# Documentary,Horror,Musical
# Biography,Documentary,Thriller
# Adventure,Documentary,Horror
# Action,Animation,Thriller
# Crime,Reality-TV
# Crime,Documentary,Reality-TV
# Comedy,Mystery,Sport
# Adventure,Animation,Horror
# Documentary,Music,Mystery
# Animation,Comedy,Documentary
# Crime,Documentary,Music
# Animation,Drama,Music
# Crime,Documentary,Sport
# Horror,Reality-TV
# Talk-Show
# Adventure,Musical,Sci-Fi
# Documentary,Family,News
# Animation,Fantasy,Thriller
# Animation,Crime,Mystery
# Fantasy,War
# Documentary,Talk-Show
# Animation,Crime,Sci-Fi
# Adventure,Documentary,Mystery
# Animation,Mystery,Thriller
# Crime,Family,Musical
# Documentary,Mystery,Sport
# Animation,Family,Music
# Action,Family,Thriller
# Action,Sci-Fi,War
# Documentary,Musical,Thriller
# Crime,Fantasy,Romance
# Crime,History,Thriller
# Horror,Music,Musical
# Documentary,Family,Fantasy
# Documentary,History,Sci-Fi
# Action,Adult,Sci-Fi
# Animation,Documentary,Music
# Biography,Thriller
# Action,Animation,Musical
# Comedy,Drama,Reality-TV
# Animation,Fantasy,Mystery
# Musical,Sport
# Biography,Documentary,Fantasy
# Family,Musical,Mystery
# Comedy,Crime,War
# Biography,Comedy,Mystery
# Documentary,Mystery,Thriller
# Documentary,Drama,News
# Family,Music,Sport
# Documentary,Family,History
# Documentary,Drama,Thriller
# Comedy,Musical,Thriller
# Horror,Talk-Show
# Adventure,Crime,Documentary
# Action,Fantasy,Western
# Animation,Documentary,News
# Adventure,Documentary,Music
# Animation,Comedy,War
# Adventure,Documentary,Western
# Animation,Music,Sci-Fi
# Documentary,Music,News
# Animation,Comedy,Mystery
# Action,Documentary,History
# Family,Sci-Fi,Sport
# Animation,Biography,Family
# Documentary,History,Western
# Adventure,Horror,Western
# Comedy,Documentary,News
# Fantasy,History,Musical
# Adventure,Documentary,Sci-Fi
# Biography,Fantasy,Horror
# Documentary,Talk-Show,Thriller
# Action,Fantasy,War
# Animation,Biography,Music
# Animation,Mystery,Sci-Fi
# Adventure,Biography,Thriller
# Action,History,Horror
# Animation,History,Musical
# Drama,Musical,Sci-Fi
# Biography,Comedy,Family
# Animation,Horror,Thriller
# Drama,Fantasy,Western
# Documentary,News,War
# Animation,Crime,Documentary
# Comedy,Thriller,Western
# Fantasy,History,Music
# Documentary,Fantasy,Mystery
# Animation,Biography,Fantasy
# Documentary,Horror,Sci-Fi
# Animation,Music,Romance
# History,Thriller,War
# Biography,Documentary,Sci-Fi
# Family,Musical,Sport
# Action,Documentary,News
# Documentary,Sci-Fi,Thriller
# Documentary,Music,Sci-Fi
# Animation,Sci-Fi,Thriller
# Documentary,Fantasy,History
# Adventure,Documentary,Reality-TV
# Adventure,Romance,Sport
# Biography,Comedy,War
# Documentary,News,Reality-TV
# Fantasy,Horror,Music
# Reality-TV,Sport
# Animation,War
# Adult,Drama,Sci-Fi
# Documentary,Sport,Thriller
# Comedy,Documentary,Thriller
# Reality-TV,Sci-Fi
# Biography,Drama,News
# Family,Horror,Thriller
# Documentary,Fantasy,Sci-Fi
# Music,Reality-TV
# Adventure,History,Sci-Fi
# Crime,Fantasy,History
# Animation,Drama,Musical
# Action,Horror,Sport
# Documentary,Mystery,News
# Animation,Romance,Sci-Fi
# Documentary,Sport,War
# Documentary,News,Thriller
# Animation,Family,History
# Documentary,Music,Western
# Comedy,Documentary,Western
# Comedy,Drama,News
# Documentary,History,Thriller
# History,Sport
# Comedy,News
# Biography,History,Mystery
# Documentary,Family,Western
# Animation,Family,Sport
# Family,Mystery,Thriller
# Action,Family,War
# Animation,Crime,Horror
# Documentary,Family,Romance
# Biography,Comedy,Fantasy
# Action,Family,Western
# Animation,Biography,Crime
# Documentary,Musical,Mystery
# Documentary,News,Romance
# Crime,Fantasy,Thriller
# Crime,Fantasy,Sci-Fi
# Animation,Romance
# Family,Fantasy,War
# Adventure,Music,Sci-Fi
# Biography,Family,Sport
# Family,History,War
# Action,Animation,Documentary
# Action,Musical,Sci-Fi
# Animation,Horror,Music
# Documentary,Horror,News
# Crime,Documentary,Family
# Documentary,Horror,Romance
# Comedy,Sport,Western
# Comedy,Sci-Fi,Western
# Crime,History,Horror
# Comedy,Sci-Fi,Sport
# Comedy,History,Horror
# Action,Biography,Fantasy
# Animation,History,Music
# Horror,Reality-TV,Sci-Fi
# Animation,Horror,Romance
# Documentary,Sport,Western
# Documentary,Musical,Sport
# Action,Mystery,Western
# Drama,Mystery,News
# Action,Animation,Biography
# Comedy,Horror,War
# Animation,History,Romance
# Family,Musical,Sci-Fi
# Animation,Documentary,Musical
# Horror,Musical,Romance
# Drama,Reality-TV
# Adventure,News
# History,Horror,Mystery
# Action,Adult,Horror
# Action,Documentary,Horror
# Adventure,History,Western
# Documentary,Family,War
# Animation,Western
# Sport,War
# Family,Mystery,Sport
# Animation,Fantasy,War
# Biography,Thriller,Western
# Documentary,Drama,Reality-TV
# Biography,Crime,Mystery
# Horror,Sci-Fi,War
# Animation,Documentary,Mystery
# Action,Adventure,Sport
# History,Sport,Thriller
# Biography,Family,History
# Comedy,Sport,Thriller
# Action,Animation,War
# Comedy,History,Sport
# Family,Horror,War
# Crime,Musical,Thriller
# Biography,Thriller,War
# Documentary,Sport,Talk-Show
# Biography,History,Horror
# Musical,Mystery,Sci-Fi
# Biography,Crime,Western
# Action,History,Western
# Family,Sci-Fi,Thriller
# Documentary,Family,Sci-Fi

# %% [markdown]
# Since the genres have too many types per movie, I will focus on the average rating and number of votes instead, then pick out the top movies.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sort the DataFrame by ratings in descending order and select the top 10 movies
top_100_movies = title_basics_with_ratings_df.sort_values(by='averageRating', ascending=False).head(100)

# Create a bar plot using Seaborn
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")

# Plot the bar chart
sns.barplot(x='genres', y='averageRating', data=top_100_movies, color='green')

# Customize the chart
plt.xticks(rotation=90)
plt.xlabel('Genres')
plt.ylabel('Average Rating')
plt.title('Top 100 Movies by Average Ratings and Their Genres')

# Show the chart
plt.show()

# %% [markdown]
# From the above chart, we note that
# 1. The genres with the the highest weighted average ratings are for instance Documentaries, Dramas, Comedies, Family etc. With this category, it means that the more significant opinions rated the  content favorably inorder for them to have a highest weighted averages.
# 2. Seeing that most categories shown above have a figure of 10, it means that most, if not all categories can have a high weighted average rating. This also means that there are other factors which contribute to the success of a movie despite which genre it falls under. This could be factors such as how well written a story is, the cast involved in the movie, the release dates etc.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sort the DataFrame by numVotes in descending order and select the top 10 movies
top_50_movies = title_basics_with_ratings_df.sort_values(by='numVotes', ascending=False).head(50)

# Create a bar plot using Seaborn
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")

# Plot the bar chart
sns.barplot(x='genres', y='numVotes', data=top_50_movies, color='yellow')

# Customize the chart
plt.xticks(rotation=90)
plt.xlabel('Genres')
plt.ylabel('Number of Votes')
plt.title('Top 50 Movies by Number of Votes and Their Genres')

# Show the chart
plt.show()

# %% [markdown]
# Again, we see that a wider variety of movies appear here, with Drama appearing the most amount of times. Action, Adventure appear frequently as well. These are the genres which have done well the most according to our graph. The appearnce of the blacklines show the confidence intervals, which are used to convey the uncertainty or variability associated with the data. This could be caused by the presence of the many genre groups as shown above by the unique figures. However, this does not hinder us to see which genres are appearing at the top of our list.

# %% [markdown]
# ### Combining Datasets 2&3

# %% [markdown]
# From the source of these datasets(https://developer.imdb.com/non-commercial-datasets/), the primary title and the original title are similar, and in the first data set it only contains one column for the movie titles. Therefore, I will choose the primary title, rename it to title, then set it as the index for both datasets, combine them and have one final dataset for final exploration.

# %%
# Change the column title
title_basics_with_ratings_df = title_basics_with_ratings_df.rename(columns={'primaryTitle': 'title'})

# %%
title_basics_with_ratings_df
# Out:
#           titleType                          title  \
# tconst
# tt0000009     movie                     Miss Jerry
# tt0000147     movie  The Corbett-Fitzsimmons Fight
# tt0000502     movie                       Bohemios
# tt0000574     movie    The Story of the Kelly Gang
# tt0000591     movie               The Prodigal Son
# ...             ...                            ...
# tt9916190     movie                      Safeguard
# tt9916270     movie       Il talento del calabrone
# tt9916428     movie            The Secret of China
# tt9916538     movie            Kuambil Lagi Hatiku
# tt9916730     movie                         6 Gunn
#
#                            originalTitle isAdult startYear endYear  \
# tconst
# tt0000009                     Miss Jerry       0      1894      \N
# tt0000147  The Corbett-Fitzsimmons Fight       0      1897      \N
# tt0000502                       Bohemios       0      1905      \N
# tt0000574    The Story of the Kelly Gang       0      1906      \N
# tt0000591              L'enfant prodigue       0      1907      \N
# ...                                  ...     ...       ...     ...
# tt9916190                      Safeguard       0      2020      \N
# tt9916270       Il talento del calabrone       0      2020      \N
# tt9916428   Hong xing zhao yao Zhong guo       0      2019      \N
# tt9916538            Kuambil Lagi Hatiku       0      2019      \N
# tt9916730                         6 Gunn       0      2017      \N
#
#           runtimeMinutes                      genres  averageRating  numVotes
# tconst
# tt0000009             45                     Romance            5.3       207
# tt0000147            100      Documentary,News,Sport            5.3       484
# tt0000502            100                          \N            4.1        15
# tt0000574             70  Action,Adventure,Biography            6.0       854
# tt0000591             90                       Drama            5.0        21
# ...                  ...                         ...            ...       ...
# tt9916190             95   Action,Adventure,Thriller            3.7       245
# tt9916270             84                    Thriller            5.8      1446
# tt9916428             \N       Adventure,History,War            3.5        17
# tt9916538            123                       Drama            8.6         7
# tt9916730            116                       Drama            7.6        11
#
# [265850 rows x 10 columns]

# %%
movie_gross_df.set_index('title', inplace=True)
movie_gross_df.head()
# Out:
#                                             studio  domestic_gross  \
# title
# Toy Story 3                                     BV     415000000.0
# Alice in Wonderland (2010)                      BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# Inception                                       WB     292600000.0
# Shrek Forever After                           P/DW     238700000.0
#
#                                              foreign_gross  year
# title
# Toy Story 3                                    652000000.0  2010
# Alice in Wonderland (2010)                     691299968.0  2010
# Harry Potter and the Deathly Hallows Part 1    664300032.0  2010
# Inception                                      535700000.0  2010
# Shrek Forever After                            513900000.0  2010

# %%
title_basics_with_ratings_df.set_index('title', inplace=True)
title_basics_with_ratings_df.head()
# Out:
#                               titleType                  originalTitle  \
# title
# Miss Jerry                        movie                     Miss Jerry
# The Corbett-Fitzsimmons Fight     movie  The Corbett-Fitzsimmons Fight
# Bohemios                          movie                       Bohemios
# The Story of the Kelly Gang       movie    The Story of the Kelly Gang
# The Prodigal Son                  movie              L'enfant prodigue
#
#                               isAdult startYear endYear runtimeMinutes  \
# title
# Miss Jerry                          0      1894      \N             45
# The Corbett-Fitzsimmons Fight       0      1897      \N            100
# Bohemios                            0      1905      \N            100
# The Story of the Kelly Gang         0      1906      \N             70
# The Prodigal Son                    0      1907      \N             90
#
#                                                    genres  averageRating  \
# title
# Miss Jerry                                        Romance            5.3
# The Corbett-Fitzsimmons Fight      Documentary,News,Sport            5.3
# Bohemios                                               \N            4.1
# The Story of the Kelly Gang    Action,Adventure,Biography            6.0
# The Prodigal Son                                    Drama            5.0
#
#                                numVotes
# title
# Miss Jerry                          207
# The Corbett-Fitzsimmons Fight       484
# Bohemios                             15
# The Story of the Kelly Gang         854
# The Prodigal Son                     21

# %% [markdown]
# ### Final Dataset

# %%
title_basics_with_ratings_moviegross_df = title_basics_with_ratings_df.join(movie_gross_df, how='inner')
title_basics_with_ratings_moviegross_df
# Out:
#                           titleType              originalTitle isAdult  \
# title
# Robin Hood                    movie                 Robin Hood       0
# Anna Karenina                 movie              Anna Karenina       0
# Jane Eyre                     movie                  Jane Eyre       0
# The Woman in Black            movie         The Woman in Black       0
# Butter                        movie                     Butter       0
# ...                             ...                        ...     ...
# Soorma                        movie                     Soorma       0
# Detective Chinatown 2         movie      Tang ren jie tan an 2       0
# Hereditary                    movie                 Hereditary       0
# How Long Will I Love U        movie      Chao shi kong tong ju       0
# Burn the Stage: The Movie     movie  Burn the Stage: The Movie       0
#
#                           startYear endYear runtimeMinutes  \
# title
# Robin Hood                     1913      \N             \N
# Anna Karenina                  1914      \N             \N
# Jane Eyre                      1914      \N             50
# The Woman in Black             1914      \N             55
# Butter                         1916      \N             \N
# ...                             ...     ...            ...
# Soorma                         2018      \N            131
# Detective Chinatown 2          2018      \N            121
# Hereditary                     2018      \N            127
# How Long Will I Love U         2018      \N            101
# Burn the Stage: The Movie      2018      \N             84
#
#                                            genres  averageRating  numVotes  \
# title
# Robin Hood                              Adventure            5.7        55
# Anna Karenina                               Drama            5.2        26
# Jane Eyre                                   Drama            7.5        20
# The Woman in Black                  Drama,Romance            5.2        45
# Butter                                         \N            6.6        12
# ...                                           ...            ...       ...
# Soorma                      Biography,Drama,Sport            7.3      5496
# Detective Chinatown 2       Action,Comedy,Mystery            6.1      2991
# Hereditary                   Drama,Horror,Mystery            7.3    358863
# How Long Will I Love U     Comedy,Fantasy,Romance            6.4      1221
# Burn the Stage: The Movie       Documentary,Music            8.5      4096
#
#                               studio  domestic_gross  foreign_gross  year
# title
# Robin Hood                      Uni.     105300000.0    216400000.0  2010
# Anna Karenina                  Focus      12800000.0     56100000.0  2012
# Jane Eyre                      Focus      11200000.0     23500000.0  2011
# The Woman in Black               CBS      54300000.0     73400000.0  2012
# Butter                          RTWC        105000.0        70700.0  2012
# ...                              ...             ...            ...   ...
# Soorma                          Sony        390000.0      6200000.0  2018
# Detective Chinatown 2             WB       2000000.0    542099968.0  2018
# Hereditary                       A24      44100000.0     35300000.0  2018
# How Long Will I Love U         WGUSA        747000.0     82100000.0  2018
# Burn the Stage: The Movie  Trafalgar       4200000.0     16100000.0  2018
#
# [1642 rows x 13 columns]

# %%
title_basics_with_ratings_moviegross_df.head(20)
# Out:
#                     titleType        originalTitle isAdult startYear endYear  \
# title
# Robin Hood              movie           Robin Hood       0      1913      \N
# Anna Karenina           movie        Anna Karenina       0      1914      \N
# Jane Eyre               movie            Jane Eyre       0      1914      \N
# The Woman in Black      movie   The Woman in Black       0      1914      \N
# Butter                  movie               Butter       0      1916      \N
# The Dictator            movie         The Dictator       0      1915      \N
# The Immigrant           movie        The Immigrant       0      1915      \N
# The Raven               movie            The Raven       0      1915      \N
# One Day                 movie              One Day       0      1916      \N
# Soldiers of Fortune     movie  Soldiers of Fortune       0      1919      \N
# Leap Year               movie            Leap Year       0      1924      \N
# Pan                     movie                  Pan       0      1922      \N
# Lights Out              movie           Lights Out       0      1923      \N
# New Year's Eve          movie            Sylvester       0      1924      \N
# The Eagle               movie            The Eagle       0      1925      \N
# The Lady                movie             The Lady       0      1925      \N
# Moana                   movie                Moana       0      1926      \N
# It                      movie                   It       0      1927      \N
# Spring Fever            movie         Spring Fever       0      1927      \N
# Skyscraper              movie           Skyscraper       0      1928      \N
#
#                     runtimeMinutes                   genres  averageRating  \
# title
# Robin Hood                      \N                Adventure            5.7
# Anna Karenina                   \N                    Drama            5.2
# Jane Eyre                       50                    Drama            7.5
# The Woman in Black              55            Drama,Romance            5.2
# Butter                          \N                       \N            6.6
# The Dictator                    \N        Adventure,Romance            7.7
# The Immigrant                   60                    Drama            7.3
# The Raven                       57          Biography,Drama            5.4
# One Day                         \N  Adventure,Drama,Romance            6.0
# Soldiers of Fortune             70          Adventure,Drama            5.9
# Leap Year                       56                   Comedy            6.1
# Pan                             96                    Drama            6.5
# Lights Out                      70              Crime,Drama            5.4
# New Year's Eve                  66                    Drama            6.2
# The Eagle                       73  Action,Adventure,Comedy            6.6
# The Lady                        96                    Drama            6.4
# Moana                           77              Documentary            6.8
# It                              72           Comedy,Romance            7.2
# Spring Fever                    78                   Comedy            6.5
# Skyscraper                      68                    Drama            5.7
#
#                      numVotes   studio  domestic_gross  foreign_gross  year
# title
# Robin Hood                 55     Uni.     105300000.0    216400000.0  2010
# Anna Karenina              26    Focus      12800000.0     56100000.0  2012
# Jane Eyre                  20    Focus      11200000.0     23500000.0  2011
# The Woman in Black         45      CBS      54300000.0     73400000.0  2012
# Butter                     12     RTWC        105000.0        70700.0  2012
# The Dictator               47     Par.      59700000.0    119700000.0  2012
# The Immigrant              44    Wein.       2000000.0      3800000.0  2014
# The Raven                 119    Rela.      16000000.0     13600000.0  2012
# One Day                    21    Focus      13800000.0     45500000.0  2011
# Soldiers of Fortune        21    RAtt.         38900.0      1500000.0  2012
# Leap Year                 354     Uni.      25900000.0      6700000.0  2010
# Pan                        45       WB      35100000.0     93300000.0  2015
# Lights Out                 14  WB (NL)      67300000.0     81600000.0  2016
# New Year's Eve            189  WB (NL)      54500000.0     87500000.0  2011
# The Eagle                2206    Focus      19500000.0      7600000.0  2011
# The Lady                  169    Cohen        355000.0      3400000.0  2012
# Moana                     707       BV     248800000.0    394600000.0  2016
# It                       3468  WB (NL)     327500000.0    372900000.0  2017
# Spring Fever             1028   Strand         10800.0       150000.0  2010
# Skyscraper                137     Uni.      68400000.0    236400000.0  2018

# %%
title_basics_with_ratings_moviegross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1642 entries, Robin Hood to Burn the Stage: The Movie
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   titleType       1642 non-null   object
#  1   originalTitle   1642 non-null   object
#  2   isAdult         1642 non-null   object
#  3   startYear       1642 non-null   object
#  4   endYear         1642 non-null   object
#  5   runtimeMinutes  1642 non-null   object
#  6   genres          1642 non-null   object
#  7   averageRating   1642 non-null   float64
#  8   numVotes        1642 non-null   int64
#  9   studio          1642 non-null   object
#  10  domestic_gross  1622 non-null   float64
#  11  foreign_gross   1642 non-null   float64
#  12  year            1642 non-null   int64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 179.6+ KB

# %% [markdown]
# After combining all three datasets, we have 1642 entries and 13 columns, and we shall use this dataset to investigate the earnings and the genres.

# %% [markdown]
# First, let us inspect the relationship between genres and the gross reveneue. I will present which genres bring in the most gross revenue by using both domestic and foreign gross columns.I will do this through the use of a stacked bar chart together with the Seaborn library. But first, let us group by the genres and both gross revenues. Because the dataset is too large, we shall pick the top 20 genres with the highest earnings.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sort the DataFrame by total gross (domestic + foreign) in descending order and select the first 10 movies
top_20_earnings = title_basics_with_ratings_moviegross_df.assign(Total_Gross=title_basics_with_ratings_moviegross_df['domestic_gross'] + title_basics_with_ratings_moviegross_df['foreign_gross']).nlargest(20, 'Total_Gross')

# Create a bar plot using Seaborn
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")

# Plot the bar chart
sns.barplot(x='Total_Gross', y='genres', data=top_20_earnings, color='orange')

# Customize the chart
plt.xlabel('Total Gross Earnings')
plt.ylabel('Genre')
plt.title('Top 20 Highest Earning Movies by Genre and Total Gross Earnings')

# Show the chart
plt.show()

# %% [markdown]
# From the above chart where we have added both gross incomes. The earnings are in terms of billions. We see that the top genres that bring in the most income are Action, Adventure, Sci-Fi, Drama and Animation. Referring to the previous charts, we can infer that movies that receive more number of votes are bound to do well. This is proven by the fact that similar categories are appearing at the top.

# %% [markdown]
# ## Evaluation
#
# From this analysis, we can see that movies tend to bring in more income from foreign countries than locally. We also see that it is quite possible for any genre to do well in the industry, depending on various factors beyond the ones we have looked into. We also see that some of the best genres that have earned billions are Animations, Dramas, Sci-Fi, Adventures and Action movies. While higher number of votes can indicate a movie's popularity and potential for success, this is just one aspect. There are other factors that contribute to the overall success of a movie.

# %% [markdown]
# ## Conclusions
#
# This analysis leads to three recommendations for Microsoft to do well in this industry;
#
# 1. Microsoft should gain a clear understanding of audience preferences at the beginning. Since the bigger audience is international, it needs to study the audience and tranlate this into the movies like themes and having film subtitles accompanied with the movies. This also translates to being culture sensitive so that the organization can reach a wider audience and be able to return more.
# 2. Microsoft should look into Animations, Dramas, Sci-Fi, Adventures and Action movies, as they have proven to be the genres with the highest ratings and most income. However, a successful genre is usally backed by a very good story. Therefore, the organization should invest in world class writes and producers to make these genres successful.
# 3. Since this is the start of a new venture for Microsoft, at least half of its success would be based on Marketing and Promotion.  Effective marketing and promotion strategies can significantly impact a movie's success and generate buzz and attract viewers, leading to higher vote counts.
#
# This analysis has only touched on a few factors such as genres, total gross revenue, number of votes and weighter average ratings. Because of this, the problem is not fully solved. More factors that need to be analysed and also contribute to the performance of a movie include Release Timing, Budget Allocation, Cast and Critical Reviews. I would conduct a more in depth analysis on these factors and provide more tangible insights to assist Microsoft in achieving its goal.
